# %%
pip list show
# Out:
# Package                  Version
# ------------------------ ------------
# absl-py                  1.4.0
# adjustText               0.8
# aiobotocore              2.5.4
# aiohttp                  3.8.5
# aioitertools             0.11.0
# aiosignal                1.3.1
# anndata                  0.9.2
# anndata2ri               1.3.1
# annotated-types          0.5.0
# annoy                    1.17.3
# anyio                    3.7.1
# appdirs                  1.4.4
# arboreto                 0.1.6
# arrow                    1.2.3
# asciitree                0.3.3
# astor                    0.8.1
# asttokens                2.4.0
# async-timeout            4.0.3
# attrs                    23.1.0
# autograd                 1.6.2
# autograd-gamma           0.5.0
# backcall                 0.2.0
# backoff                  2.2.1
# beautifulsoup4           4.12.2
# binaryornot              0.4.4
# biopython                1.81
# bioservices              1.11.2
# ...
